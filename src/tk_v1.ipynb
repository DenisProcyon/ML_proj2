# %% [markdown]
# ### **ML Project- Position prediction for football players**

# %%
import pandas as pd

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
# Out:
#        id   short_name  overall  potential  value_eur  wage_eur birthday_date  \
# 0  216302    E. García       71         71  1400000.0     10000    1989-12-28
# 1  237867   D. Cancola       65         71  1000000.0      2000    1996-10-23
# 2  253472      E. Kahl       65         77  1600000.0      2000    2001-09-27
# 3  223994    S. Mugoša       72         72  2300000.0      5000    1992-02-26
# 4  251635  A. Țigănașu       65         65   525000.0      3000    1990-06-12
#
#    height_cm  weight_kg                  club_name  ...  \
# 0        176         73  Club Atlético de San Luis  ...
# 1        183         73             Ross County FC  ...
# 2        178         69                  Aarhus GF  ...
# 3        188         81          Incheon United FC  ...
# 4        179         74                FC Botoşani  ...
#
#   defending_marking_awareness  defending_standing_tackle  \
# 0                          65                         66
# 1                          65                         61
# 2                          60                         58
# 3                          16                         22
# 4                          64                         61
#
#    defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                        65                 14                   11
# 1                        58                 10                   13
# 2                        59                 10                   10
# 3                        19                 16                   15
# 4                        58                 12                    5
#
#    goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   12                      12                    12
# 1                    7                       6                    11
# 2                    8                      10                    11
# 3                   13                       8                     9
# 4                   11                      12                    15
#
#   goalkeeping_speed  position
# 0               NaN        LB
# 1               NaN       LDM
# 2               NaN       LWB
# 3               NaN        LS
# 4               NaN        LB
#
# [5 rows x 70 columns]

# %%
df_train.position.value_counts()
# Out:
# position
# RCB    631
# GK     631
# LCB    631
# RB     463
# LB     463
# ST     428
# RCM    423
# LCM    423
# RM     369
# LM     369
# CAM    263
# RDM    201
# LS     201
# RS     201
# LDM    201
# CB     167
# RW     166
# LW     166
# CDM    151
# LWB    104
# RWB    104
# CM      75
# LF      32
# RF      32
# Name: count, dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6895 entries, 0 to 6894
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           6895 non-null   int64
#  1   short_name                   6895 non-null   object
#  2   overall                      6895 non-null   int64
#  3   potential                    6895 non-null   int64
#  4   value_eur                    6893 non-null   float64
#  5   wage_eur                     6895 non-null   int64
#  6   birthday_date                6895 non-null   object
#  7   height_cm                    6895 non-null   int64
#  8   weight_kg                    6895 non-null   int64
#  9   club_name                    6895 non-null   object
#  10  league_name                  6895 non-null   object
#  11  league_level                 6895 non-null   int64
#  12  club_jersey_number           6895 non-null   int64
#  13  club_loaned_from             351 non-null    object
#  14  club_joined                  6544 non-null   object
#  15  club_contract_valid_until    6895 non-null   int64
#  16  nationality_name             6895 non-null   object
#  17  nation_jersey_number         413 non-null    float64
#  18  preferred_foot               6895 non-null   object
#  19  weak_foot                    6895 non-null   int64
#  20  skill_moves                  6895 non-null   int64
#  21  international_reputation     6895 non-null   int64
#  22  work_rate                    6895 non-null   object
#  23  body_type                    6895 non-null   object
#  24  real_face                    6895 non-null   object
#  25  release_clause_eur           6542 non-null   float64
#  26  player_tags                  771 non-null    object
#  27  player_traits                4306 non-null   object
#  28  pace                         6264 non-null   float64
#  29  shooting                     6264 non-null   float64
#  30  passing                      6264 non-null   float64
#  31  dribbling                    6264 non-null   float64
#  32  defending                    6264 non-null   float64
#  33  physic                       6264 non-null   float64
#  34  attacking_crossing           6895 non-null   int64
#  35  attacking_finishing          6895 non-null   int64
#  36  attacking_heading_accuracy   6895 non-null   int64
#  37  attacking_short_passing      6895 non-null   int64
#  38  attacking_volleys            6895 non-null   int64
#  39  skill_dribbling              6895 non-null   int64
#  40  skill_curve                  6895 non-null   int64
#  41  skill_fk_accuracy            6895 non-null   int64
#  42  skill_long_passing           6895 non-null   int64
#  43  skill_ball_control           6895 non-null   int64
#  44  movement_acceleration        6895 non-null   int64
#  45  movement_sprint_speed        6895 non-null   int64
#  46  movement_agility             6895 non-null   int64
#  47  movement_reactions           6895 non-null   int64
#  48  movement_balance             6895 non-null   int64
#  49  power_shot_power             6895 non-null   int64
#  50  power_jumping                6895 non-null   int64
#  51  power_stamina                6895 non-null   int64
#  52  power_strength               6895 non-null   int64
#  53  power_long_shots             6895 non-null   int64
#  54  mentality_aggression         6895 non-null   int64
#  55  mentality_interceptions      6895 non-null   int64
#  56  mentality_positioning        6895 non-null   int64
#  57  mentality_vision             6895 non-null   int64
#  58  mentality_penalties          6895 non-null   int64
#  59  mentality_composure          6895 non-null   int64
#  60  defending_marking_awareness  6895 non-null   int64
#  61  defending_standing_tackle    6895 non-null   int64
#  62  defending_sliding_tackle     6895 non-null   int64
#  63  goalkeeping_diving           6895 non-null   int64
#  64  goalkeeping_handling         6895 non-null   int64
#  65  goalkeeping_kicking          6895 non-null   int64
#  66  goalkeeping_positioning      6895 non-null   int64
#  67  goalkeeping_reflexes         6895 non-null   int64
#  68  goalkeeping_speed            631 non-null    float64
#  69  position                     6895 non-null   object
# dtypes: float64(10), int64(46), object(14)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Categorical Data Preprocessing

# %%
df_train.select_dtypes(include=['object', 'category']).columns
# Out:
# Index(['short_name', 'birthday_date', 'club_name', 'league_name',
#        'club_loaned_from', 'club_joined', 'nationality_name', 'preferred_foot',
#        'work_rate', 'body_type', 'real_face', 'player_tags', 'player_traits',
#        'position'],
#       dtype='object')

# %%
duplicates = df_train[df_train.duplicated()]

# %%
df_train = df_train.drop_duplicates()
df_test = df_test.drop_duplicates()

# %%
df_train.club_joined.dtypes
# Out:
# dtype('O')

# %%
df_train.select_dtypes(include=['object', 'category']).columns
# Out:
# Index(['short_name', 'birthday_date', 'club_name', 'league_name',
#        'club_loaned_from', 'club_joined', 'nationality_name', 'preferred_foot',
#        'work_rate', 'body_type', 'real_face', 'player_tags', 'player_traits',
#        'position'],
#       dtype='object')

# %%
df_train['birthday_date'] = pd.to_datetime(df_train['birthday_date']).dt.date
df_test['birthday_date'] = pd.to_datetime(df_test['birthday_date']).dt.date

# %%
# df_train['club_joined'] = pd.to_datetime(df_train['club_joined']).dt.date

# %%
# df_train['club_contract_valid_until'] = pd.to_datetime(df_train['club_contract_valid_until'])
df_train['club_joined'] = pd.to_datetime(df_train['club_joined'])
df_test['club_joined'] = pd.to_datetime(df_test['club_joined'])

# %%
# df_train['club_contract_valid_until'].dt.year

# %%
# Calculate the playing experience (in days, years, or months)
df_train['playing_experience'] = df_train['club_contract_valid_until'] - df_train['club_joined'].dt.year
df_test['playing_experience'] = df_test['club_contract_valid_until'] - df_test['club_joined'].dt.year

# %%
df_train['playing_experience']
# Out:
# 0       5.0
# 1       1.0
# 2       5.0
# 3       5.0
# 4       3.0
#        ...
# 6890    2.0
# 6891    3.0
# 6892    3.0
# 6893    7.0
# 6894    1.0
# Name: playing_experience, Length: 6895, dtype: float64

# %%
# Calculate age
from datetime import datetime

today = pd.Timestamp(datetime.today())
df_train['Age'] = df_train['birthday_date'].apply(lambda dob: today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day)))
df_test['Age'] = df_test['birthday_date'].apply(lambda dob: today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day)))

# %%
# Split the 'work_rate' column into two new columns
df_train[['attacking_work_rate', 'defensive_work_rate']] = df_train['work_rate'].str.split('/', expand=True)
df_test[['attacking_work_rate', 'defensive_work_rate']] = df_test['work_rate'].str.split('/', expand=True)

# Now check the first few rows to verify
print(df_train[['attacking_work_rate', 'defensive_work_rate']].head())
# Out:
#   attacking_work_rate defensive_work_rate
# 0              Medium                High
# 1              Medium              Medium
# 2                High              Medium
# 3                High              Medium
# 4              Medium                High

# %%
work_rate_map = {'Low': 1, 'Medium': 2, 'High': 3}

# Replace the values in both 'attacking_work_rate' and 'defensive_work_rate' columns
df_train['attacking_work_rate'] = df_train['attacking_work_rate'].replace(work_rate_map)
df_train['defensive_work_rate'] = df_train['defensive_work_rate'].replace(work_rate_map)

# Replace the values in both 'attacking_work_rate' and 'defensive_work_rate' columns
df_test['attacking_work_rate'] = df_test['attacking_work_rate'].replace(work_rate_map)
df_test['defensive_work_rate'] = df_test['defensive_work_rate'].replace(work_rate_map)
# Out:
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/2659246239.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['attacking_work_rate'] = df_train['attacking_work_rate'].replace(work_rate_map)
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/2659246239.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['defensive_work_rate'] = df_train['defensive_work_rate'].replace(work_rate_map)
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/2659246239.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['attacking_work_rate'] = df_test['attacking_work_rate'].replace(work_rate_map)
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/2659246239.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['defensive_work_rate'] = df_test['defensive_work_rate'].replace(work_rate_map)

# %%
print(df_train[['attacking_work_rate', 'defensive_work_rate']].head())
# Out:
#    attacking_work_rate  defensive_work_rate
# 0                    2                    3
# 1                    2                    2
# 2                    3                    2
# 3                    3                    2
# 4                    2                    3

# %%
df_train.drop(['goalkeeping_speed', 'player_tags', 'nation_jersey_number', 'club_loaned_from', 'club_contract_valid_until', 'birthday_date', 'club_joined',
              'work_rate','short_name', 'nationality_name', 'league_name', 'nation_jersey_number', 'player_traits', 'club_name' ], axis=1, inplace=True)
df_test.drop(['goalkeeping_speed', 'player_tags', 'nation_jersey_number', 'club_loaned_from', 'club_contract_valid_until', 'club_joined', 'birthday_date',
              'work_rate', 'short_name', 'nationality_name', 'league_name', 'nation_jersey_number', 'player_traits', 'club_name'
             ], axis=1, inplace=True)

# %%
df_train.columns
# Out:
# Index(['id', 'overall', 'potential', 'value_eur', 'wage_eur', 'height_cm',
#        'weight_kg', 'league_level', 'club_jersey_number', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'body_type',
#        'real_face', 'release_clause_eur', 'pace', 'shooting', 'passing',
#        'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'position',
#        'playing_experience', 'Age', 'attacking_work_rate',
#        'defensive_work_rate'],
#       dtype='object')

# %%
categorical_columns = ['preferred_foot', 'body_type', 'real_face']
df_train = pd.get_dummies(df_train, columns=categorical_columns)
df_test = pd.get_dummies(df_test, columns=categorical_columns)

# %%
print(df_train.columns)
# Out:
# Index(['id', 'overall', 'potential', 'value_eur', 'wage_eur', 'height_cm',
#        'weight_kg', 'league_level', 'club_jersey_number', 'weak_foot',
#        'skill_moves', 'international_reputation', 'release_clause_eur', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'position',
#        'playing_experience', 'Age', 'attacking_work_rate',
#        'defensive_work_rate', 'preferred_foot_Left', 'preferred_foot_Right',
#        'body_type_Lean (170-)', 'body_type_Lean (170-185)',
#        'body_type_Lean (185+)', 'body_type_Normal (170-)',
#        'body_type_Normal (170-185)', 'body_type_Normal (185+)',
#        'body_type_Stocky (170-)', 'body_type_Stocky (170-185)',
#        'body_type_Stocky (185+)', 'body_type_Unique', 'real_face_No',
#        'real_face_Yes'],
#       dtype='object')

# %%
df_train.columns[df_train.isnull().any()]
# Out:
# Index(['value_eur', 'release_clause_eur', 'pace', 'shooting', 'passing',
#        'dribbling', 'defending', 'physic', 'playing_experience'],
#       dtype='object')

# %%
# List of columns to check
columns_to_check = ['value_eur', 'release_clause_eur', 'pace', 'shooting', 'passing',
                    'dribbling', 'defending', 'physic', 'playing_experience']

# Calculate the percentage of missing values for each specified column
missing_percentage = df_train[columns_to_check].isnull().mean() * 100

# Display the results
print(missing_percentage)
# Out:
# value_eur             0.029007
# release_clause_eur    5.119652
# pace                  9.151559
# shooting              9.151559
# passing               9.151559
# dribbling             9.151559
# defending             9.151559
# physic                9.151559
# playing_experience    5.090645
# dtype: float64

# %%
# List of columns to check
columns_to_check = ['value_eur', 'release_clause_eur', 'pace', 'shooting', 'passing',
                    'dribbling', 'defending', 'physic', 'playing_experience']

# Calculate the percentage of missing values for each specified column
missing_percentage = df_train[columns_to_check].describe()

# Display the results
print(missing_percentage)
# Out:
#           value_eur  release_clause_eur         pace     shooting  \
# count  6.893000e+03        6.542000e+03  6264.000000  6264.000000
# mean   4.320388e+06        8.148991e+06    68.535121    54.300128
# std    1.052554e+07        2.056057e+07    11.777003    14.386234
# min    2.500000e+04        3.900000e+04    28.000000    18.000000
# 25%    7.250000e+05        1.100000e+06    62.000000    43.000000
# 50%    1.400000e+06        2.300000e+06    70.000000    57.000000
# 75%    2.900000e+06        5.400000e+06    77.000000    65.000000
# max    1.940000e+08        3.735000e+08    97.000000    94.000000
#
#            passing    dribbling    defending       physic  playing_experience
# count  6264.000000  6264.000000  6264.000000  6264.000000         6544.000000
# mean     60.068487    64.570243    55.549968    68.293582            3.677262
# std       9.603023     9.380977    15.616228     8.548078            2.446817
# min      25.000000    29.000000    16.000000    31.000000            0.000000
# 25%      54.000000    59.000000    43.000000    63.000000            2.000000
# 50%      60.000000    65.000000    61.000000    69.000000            3.000000
# 75%      67.000000    71.000000    67.000000    74.000000            5.000000
# max      93.000000    95.000000    89.000000    90.000000           20.000000

# %%
columns_m = ['value_eur', 'release_clause_eur', 'pace', 'shooting', 'passing',
                    'dribbling', 'defending', 'physic', 'playing_experience']

# Fill missing values in these columns with the mean of each column
for col in columns_m:
    df_train[col].fillna(df_train[col].mean(), inplace=True)
    df_test[col].fillna(df_test[col].mean(), inplace=True)
# Out:
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/3223627248.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train[col].fillna(df_train[col].mean(), inplace=True)
# /var/folders/sj/60qhcj1n1zzch8_rq_k0sz940000gn/T/ipykernel_74197/3223627248.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test[col].fillna(df_test[col].mean(), inplace=True)

# %%
df_train.shape
# Out:
# (6895, 72)

# %%
# df_train.dropna( axis=0, inplace=True)
# df_test.dropna( axis=0, inplace=True)

# %%
df_test.shape
# Out:
# (767, 71)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6895 entries, 0 to 6894
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           6895 non-null   int64
#  1   overall                      6895 non-null   int64
#  2   potential                    6895 non-null   int64
#  3   value_eur                    6895 non-null   float64
#  4   wage_eur                     6895 non-null   int64
#  5   height_cm                    6895 non-null   int64
#  6   weight_kg                    6895 non-null   int64
#  7   league_level                 6895 non-null   int64
#  8   club_jersey_number           6895 non-null   int64
#  9   weak_foot                    6895 non-null   int64
#  10  skill_moves                  6895 non-null   int64
#  11  international_reputation     6895 non-null   int64
#  12  release_clause_eur           6895 non-null   float64
#  13  pace                         6895 non-null   float64
#  14  shooting                     6895 non-null   float64
#  15  passing                      6895 non-null   float64
#  16  dribbling                    6895 non-null   float64
#  17  defending                    6895 non-null   float64
#  18  physic                       6895 non-null   float64
#  19  attacking_crossing           6895 non-null   int64
#  20  attacking_finishing          6895 non-null   int64
#  21  attacking_heading_accuracy   6895 non-null   int64
#  22  attacking_short_passing      6895 non-null   int64
#  23  attacking_volleys            6895 non-null   int64
#  24  skill_dribbling              6895 non-null   int64
#  25  skill_curve                  6895 non-null   int64
#  26  skill_fk_accuracy            6895 non-null   int64
#  27  skill_long_passing           6895 non-null   int64
#  28  skill_ball_control           6895 non-null   int64
#  29  movement_acceleration        6895 non-null   int64
#  30  movement_sprint_speed        6895 non-null   int64
#  31  movement_agility             6895 non-null   int64
#  32  movement_reactions           6895 non-null   int64
#  33  movement_balance             6895 non-null   int64
#  34  power_shot_power             6895 non-null   int64
#  35  power_jumping                6895 non-null   int64
#  36  power_stamina                6895 non-null   int64
#  37  power_strength               6895 non-null   int64
#  38  power_long_shots             6895 non-null   int64
#  39  mentality_aggression         6895 non-null   int64
#  40  mentality_interceptions      6895 non-null   int64
#  41  mentality_positioning        6895 non-null   int64
#  42  mentality_vision             6895 non-null   int64
#  43  mentality_penalties          6895 non-null   int64
#  44  mentality_composure          6895 non-null   int64
#  45  defending_marking_awareness  6895 non-null   int64
#  46  defending_standing_tackle    6895 non-null   int64
#  47  defending_sliding_tackle     6895 non-null   int64
#  48  goalkeeping_diving           6895 non-null   int64
#  49  goalkeeping_handling         6895 non-null   int64
#  50  goalkeeping_kicking          6895 non-null   int64
#  51  goalkeeping_positioning      6895 non-null   int64
#  52  goalkeeping_reflexes         6895 non-null   int64
#  53  position                     6895 non-null   object
#  54  playing_experience           6895 non-null   float64
#  55  Age                          6895 non-null   int64
#  56  attacking_work_rate          6895 non-null   int64
#  57  defensive_work_rate          6895 non-null   int64
#  58  preferred_foot_Left          6895 non-null   bool
#  59  preferred_foot_Right         6895 non-null   bool
#  60  body_type_Lean (170-)        6895 non-null   bool
#  61  body_type_Lean (170-185)     6895 non-null   bool
#  62  body_type_Lean (185+)        6895 non-null   bool
#  63  body_type_Normal (170-)      6895 non-null   bool
#  64  body_type_Normal (170-185)   6895 non-null   bool
#  65  body_type_Normal (185+)      6895 non-null   bool
#  66  body_type_Stocky (170-)      6895 non-null   bool
#  67  body_type_Stocky (170-185)   6895 non-null   bool
#  68  body_type_Stocky (185+)      6895 non-null   bool
#  69  body_type_Unique             6895 non-null   bool
#  70  real_face_No                 6895 non-null   bool
#  71  real_face_Yes                6895 non-null   bool
# dtypes: bool(14), float64(9), int64(48), object(1)
# memory usage: 3.1+ MB

# %%
df_train.preferred_foot_Left
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 6890    False
# 6891    False
# 6892     True
# 6893     True
# 6894    False
# Name: preferred_foot_Left, Length: 6895, dtype: bool

# %%
X_train = df_train.drop('position', axis=1)  # Features
y_train = df_train['position']              # Target

# %%
X_train.drop(columns='id', inplace=True)
df_test1 = df_test.drop(columns='id')
X_train
# Out:
#       overall  potential   value_eur  wage_eur  height_cm  weight_kg  \
# 0          71         71   1400000.0     10000        176         73
# 1          65         71   1000000.0      2000        183         73
# 2          65         77   1600000.0      2000        178         69
# 3          72         72   2300000.0      5000        188         81
# 4          65         65    525000.0      3000        179         74
# ...       ...        ...         ...       ...        ...        ...
# 6890       59         66    425000.0      2000        180         65
# 6891       83         83  28500000.0     61000        183         80
# 6892       70         80   3400000.0      6000        177         73
# 6893       71         71   1300000.0      7000        176         70
# 6894       66         70   1100000.0      4000        188         74
#
#       league_level  club_jersey_number  weak_foot  skill_moves  ...  \
# 0                1                  29          5            3  ...
# 1                1                   4          3            2  ...
# 2                1                  19          3            3  ...
# 3                1                   9          3            3  ...
# 4                1                  30          2            2  ...
# ...            ...                 ...        ...          ...  ...
# 6890             4                  17          3            2  ...
# 6891             1                  15          4            4  ...
# 6892             1                  25          3            2  ...
# 6893             1                  19          3            2  ...
# 6894             1                  27          3            2  ...
#
#       body_type_Lean (185+)  body_type_Normal (170-)  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                      True                    False
# 4                     False                    False
# ...                     ...                      ...
# 6890                  False                    False
# 6891                  False                    False
# 6892                  False                    False
# 6893                  False                    False
# 6894                   True                    False
#
#       body_type_Normal (170-185)  body_type_Normal (185+)  \
# 0                           True                    False
# 1                          False                    False
# 2                           True                    False
# 3                          False                    False
# 4                           True                    False
# ...                          ...                      ...
# 6890                        True                    False
# 6891                        True                    False
# 6892                        True                    False
# 6893                       False                    False
# 6894                       False                    False
#
#       body_type_Stocky (170-)  body_type_Stocky (170-185)  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
# ...                       ...                         ...
# 6890                    False                       False
# 6891                    False                       False
# 6892                    False                       False
# 6893                    False                       False
# 6894                    False                       False
#
#       body_type_Stocky (185+)  body_type_Unique  real_face_No  real_face_Yes
# 0                       False             False          True          False
# 1                       False             False          True          False
# 2                       False             False          True          False
# 3                       False             False          True          False
# 4                       False             False          True          False
# ...                       ...               ...           ...            ...
# 6890                    False             False          True          False
# 6891                    False             False         False           True
# 6892                    False             False          True          False
# 6893                    False             False          True          False
# 6894                    False             False          True          False
#
# [6895 rows x 70 columns]

# %%
X1_test= df_test1

# %% [markdown]
# We are using SMOTE (Synthetic Minority Oversampling Technique) to deal with the data imbalance. It's used to address class imbalance in classification problems (works by creating synthetic samples for the minority class rather than duplicating them).

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:", y_train_smote.value_counts())
# Out:
# Before SMOTE: position
# RCB    631
# GK     631
# LCB    631
# RB     463
# LB     463
# ST     428
# RCM    423
# LCM    423
# RM     369
# LM     369
# CAM    263
# RDM    201
# LS     201
# RS     201
# LDM    201
# CB     167
# RW     166
# LW     166
# CDM    151
# LWB    104
# RWB    104
# CM      75
# LF      32
# RF      32
# Name: count, dtype: int64
# After SMOTE: position
# LB     631
# LDM    631
# RF     631
# LF     631
# RWB    631
# LM     631
# RS     631
# ST     631
# CB     631
# CAM    631
# RDM    631
# CDM    631
# RCB    631
# RB     631
# LCB    631
# LW     631
# RCM    631
# RM     631
# LCM    631
# GK     631
# RW     631
# LS     631
# LWB    631
# CM     631
# Name: count, dtype: int64

# %%
X_train_smote.head()
# Out:
#    overall  potential  value_eur  wage_eur  height_cm  weight_kg  \
# 0       71         71  1400000.0     10000        176         73
# 1       65         71  1000000.0      2000        183         73
# 2       65         77  1600000.0      2000        178         69
# 3       72         72  2300000.0      5000        188         81
# 4       65         65   525000.0      3000        179         74
#
#    league_level  club_jersey_number  weak_foot  skill_moves  ...  \
# 0             1                  29          5            3  ...
# 1             1                   4          3            2  ...
# 2             1                  19          3            3  ...
# 3             1                   9          3            3  ...
# 4             1                  30          2            2  ...
#
#    body_type_Lean (185+)  body_type_Normal (170-)  body_type_Normal (170-185)  \
# 0                  False                    False                        True
# 1                  False                    False                       False
# 2                  False                    False                        True
# 3                   True                    False                       False
# 4                  False                    False                        True
#
#    body_type_Normal (185+)  body_type_Stocky (170-)  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
#    body_type_Stocky (170-185)  body_type_Stocky (185+)  body_type_Unique  \
# 0                       False                    False             False
# 1                       False                    False             False
# 2                       False                    False             False
# 3                       False                    False             False
# 4                       False                    False             False
#
#    real_face_No  real_face_Yes
# 0          True          False
# 1          True          False
# 2          True          False
# 3          True          False
# 4          True          False
#
# [5 rows x 70 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
# Splitting the data into training and testing sets (80% training, 20% testing)
# X_train, X_test, y_train, y_test = train_test_split(X_train_smote, y_train_smote, test_size=0.2, random_state=42)

# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42, n_estimators=100)

# Fit the model
rf_model.fit(X_train_smote, y_train_smote)



# # Calculate F1 score
# f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' handles multiclass imbalance
# print(f'F1 Score: {f1:.2f}')
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X1_test)

# %%
predictions_df = pd.DataFrame({
    'id': df_test['id'],  
    'position': y_pred        # 'y_pred' contains the model predictions
})

# Export the DataFrame to a CSV file
predictions_df.to_csv('predictions.csv', index=False)

print("CSV file with id and predictions has been saved.")
# Out:
# CSV file with id and predictions has been saved.
